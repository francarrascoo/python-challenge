# %% [markdown]
# <a href="https://colab.research.google.com/github/francarrascoo/python-challenge/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
#Tienda 1
lista_precio = tienda["Precio"].tolist()
suma_precios = sum(lista_precio)
print("Ingreso total tienda 1: ", suma_precios)
# Out:
# Ingreso total tienda 1:  1150880400.0

# %%
#Tienda 2
lista_precio = tienda2["Precio"].tolist()
suma_precios = sum(lista_precio)
print("Ingreso total tienda 2: ", suma_precios)
# Out:
# Ingreso total tienda 2:  1116343500.0

# %%
#Tienda 3
lista_precio = tienda3["Precio"].tolist()
suma_precios = sum(lista_precio)
print("Ingreso total tienda 3: ", suma_precios)
# Out:
# Ingreso total tienda 3:  1098019600.0

# %%
#Tienda 4
lista_precio = tienda4["Precio"].tolist()
suma_precios = sum(lista_precio)
print("Ingreso total tienda 4: ", suma_precios)
# Out:
# Ingreso total tienda 4:  1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
#Tienda 1

ventas_por_categoria = tienda.groupby("Categoría del Producto")["Producto"].count()
print(f"Ventas por categoría Tienda 1 \n{ventas_por_categoria}")
# Out:
# Ventas por categoría Tienda 1
# Categoría del Producto
# Artículos para el hogar    171
# Deportes y diversión       284
# Electrodomésticos          312
# Electrónicos               448
# Instrumentos musicales     182
# Juguetes                   324
# Libros                     173
# Muebles                    465
# Name: Producto, dtype: int64

# %%
#Tienda 2

ventas_por_categoria = tienda2.groupby("Categoría del Producto")["Producto"].count()
print(f"Ventas por categoría Tienda 2 \n{ventas_por_categoria}")
# Out:
# Ventas por categoría Tienda 2
# Categoría del Producto
# Artículos para el hogar    181
# Deportes y diversión       275
# Electrodomésticos          305
# Electrónicos               422
# Instrumentos musicales     224
# Juguetes                   313
# Libros                     197
# Muebles                    442
# Name: Producto, dtype: int64

# %%
#Tienda 3

ventas_por_categoria = tienda3.groupby("Categoría del Producto")["Producto"].count()
print(f"Ventas por categoría Tienda 3 \n{ventas_por_categoria}")
# Out:
# Ventas por categoría Tienda 3
# Categoría del Producto
# Artículos para el hogar    177
# Deportes y diversión       277
# Electrodomésticos          278
# Electrónicos               451
# Instrumentos musicales     177
# Juguetes                   315
# Libros                     185
# Muebles                    499
# Name: Producto, dtype: int64

# %%
#Tienda 4

ventas_por_categoria = tienda4.groupby("Categoría del Producto")["Producto"].count()
print(f"Ventas por categoría Tienda 4 \n{ventas_por_categoria}")
# Out:
# Categoría del Producto
# Artículos para el hogar    201
# Deportes y diversión       277
# Electrodomésticos          254
# Electrónicos               451
# Instrumentos musicales     170
# Juguetes                   338
# Libros                     187
# Muebles                    480
# Name: Producto, dtype: int64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
#Tienda 1

calificaciones = tienda["Calificación"].tolist()
promedio = round(sum(calificaciones) / len(calificaciones), 2)
print("Promedio calificación Tienda 1: ", promedio)
# Out:
# Promedio calificación Tienda 1:  3.98

# %%
#Tienda 2

calificaciones = tienda2["Calificación"].tolist()
promedio = round(sum(calificaciones) / len(calificaciones), 2)
print("Promedio calificación Tienda 2: ", promedio)
# Out:
# Promedio calificación Tienda 2:  4.04

# %%
#Tienda 3

calificaciones = tienda3["Calificación"].tolist()
promedio = round(sum(calificaciones) / len(calificaciones), 2)
print("Promedio calificación Tienda 3: ", promedio)
# Out:
# Promedio calificación Tienda 3:  4.05

# %%
#Tienda 4

calificaciones = tienda4["Calificación"].tolist()
promedio = round(sum(calificaciones) / len(calificaciones), 2)
print("Promedio calificación Tienda 4: ", promedio)
# Out:
# Promedio calificación Tienda 4:  4.0

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
#Tienda 1

ventas_por_producto = tienda['Producto'].value_counts()
print(ventas_por_producto)

cantidad_mas_vendida = ventas_por_producto.max()
productos_mas_vendidos = ventas_por_producto[ventas_por_producto == cantidad_mas_vendida].index.tolist()

cantidad_menos_vendida = ventas_por_producto.min()
productos_menos_vendidos = ventas_por_producto[ventas_por_producto == cantidad_menos_vendida].index.tolist()

print(f"Productos más vendidos (con {cantidad_mas_vendida} unidades): {productos_mas_vendidos}")
print(f"Productos menos vendidos (con {cantidad_menos_vendida} unidades): {productos_menos_vendidos}")
# Out:
# Producto
# Microondas                     60
# TV LED UHD 4K                  60
# Armario                        60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Vaso térmico                   54
# Refrigerador                   54
# Impresora                      54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Lavadora de ropa               47
# Guitarra eléctrica             47
# Guitarra acústica              46
# Sofá reclinable                46
# Silla de oficina               46
# Estufa                         45
# Cama box                       44
# Kit de bancas                  44
# ...

# %%
#Tienda 2

ventas_por_producto = tienda2['Producto'].value_counts()
print(ventas_por_producto)

cantidad_mas_vendida = ventas_por_producto.max()
productos_mas_vendidos = ventas_por_producto[ventas_por_producto == cantidad_mas_vendida].index.tolist()

cantidad_menos_vendida = ventas_por_producto.min()
productos_menos_vendidos = ventas_por_producto[ventas_por_producto == cantidad_menos_vendida].index.tolist()

print(f"Productos más vendidos (con {cantidad_mas_vendida} unidades): {productos_mas_vendidos}")
print(f"Productos menos vendidos (con {cantidad_menos_vendida} unidades): {productos_menos_vendidos}")
# Out:
# Producto
# Iniciando en programación      65
# Microondas                     62
# Batería                        61
# Guitarra acústica              58
# Pandereta                      58
# Secadora de ropa               57
# Iphone 15                      55
# Bloques de construcción        54
# Armario                        54
# Set de ollas                   52
# Cuerda para saltar             50
# Lavadora de ropa               49
# Silla de oficina               49
# Refrigerador                   49
# Muñeca bebé                    48
# Carrito de control remoto      47
# Guitarra eléctrica             47
# Cama box                       47
# Vaso térmico                   47
# Modelado predictivo            46
# Balón de voleibol              46
# Set de vasos                   46
# Lavavajillas                   46
# Kit de bancas                  45
# Cama king                      45
# Bicicleta                      45
# Mochila                        45
# ...

# %%
#Tienda 3

ventas_por_producto = tienda3['Producto'].value_counts()
print(ventas_por_producto)

cantidad_mas_vendida = ventas_por_producto.max()
productos_mas_vendidos = ventas_por_producto[ventas_por_producto == cantidad_mas_vendida].index.tolist()

cantidad_menos_vendida = ventas_por_producto.min()
productos_menos_vendidos = ventas_por_producto[ventas_por_producto == cantidad_menos_vendida].index.tolist()

print(f"Productos más vendidos (con {cantidad_mas_vendida} unidades): {productos_mas_vendidos}")
print(f"Productos menos vendidos (con {cantidad_menos_vendida} unidades): {productos_menos_vendidos}")
# Out:
# Producto
# Kit de bancas                  57
# Mesa de comedor                56
# Cama king                      56
# Set de ollas                   55
# Mesa de noche                  55
# Smart TV                       54
# Estufa                         53
# Cuerda para saltar             53
# Modelado predictivo            53
# Carrito de control remoto      52
# Lavavajillas                   52
# Bicicleta                      52
# Juego de mesa                  52
# Pandereta                      51
# Impresora                      50
# Refrigerador                   50
# Balón de baloncesto            50
# Armario                        49
# Balón de voleibol              48
# Tablet ABXY                    48
# Sillón                         47
# Guitarra acústica              47
# Olla de presión                47
# Ajedrez de madera              47
# Ciencia de datos con Python    46
# Iphone 15                      46
# Dinosaurio Rex                 46
# ...

# %%
#Tienda 4

ventas_por_producto = tienda4['Producto'].value_counts()
print(ventas_por_producto)

cantidad_mas_vendida = ventas_por_producto.max()
productos_mas_vendidos = ventas_por_producto[ventas_por_producto == cantidad_mas_vendida].index.tolist()

cantidad_menos_vendida = ventas_por_producto.min()
productos_menos_vendidos = ventas_por_producto[ventas_por_producto == cantidad_menos_vendida].index.tolist()

print(f"Productos más vendidos (con {cantidad_mas_vendida} unidades): {productos_mas_vendidos}")
print(f"Productos menos vendidos (con {cantidad_menos_vendida} unidades): {productos_menos_vendidos}")
# Out:
# Producto
# Cama box                       62
# Cubertería                     59
# Dashboards con Power BI        56
# Cama king                      56
# Carrito de control remoto      55
# Mesa de comedor                55
# Mesa de noche                  55
# Smart TV                       54
# Bloques de construcción        54
# Pandereta                      52
# Impresora                      50
# Modelado predictivo            50
# Asistente virtual              50
# Set de ollas                   50
# Balón de baloncesto            50
# Vaso térmico                   48
# Iphone 15                      48
# Muñeca bebé                    48
# Batería                        48
# Balón de voleibol              48
# Juego de mesa                  48
# Microondas                     48
# Estufa                         47
# Cubo mágico 8x8                47
# Sofá reclinable                47
# Dinosaurio Rex                 47
# Olla de presión                46
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
#Tienda 1

total_envio = sum(tienda['Costo de envío'])
cantidad = len(tienda['Costo de envío'])

promedio_envio = total_envio / cantidad if cantidad > 0 else 0

print(f"Costo de envío promedio general en la Tienda 1: {promedio_envio:.1f}")
# Out:
# Costo de envío promedio general en la Tienda 1: 26018.6

# %%
#Tienda 2

total_envio = sum(tienda2['Costo de envío'])
cantidad = len(tienda2['Costo de envío'])

promedio_envio = total_envio / cantidad if cantidad > 0 else 0

print(f"Costo de envío promedio general en la Tienda 2: {promedio_envio:.1f}")
# Out:
# Costo de envío promedio general en la Tienda 2: 25216.2

# %%
#Tienda 3

total_envio = sum(tienda3['Costo de envío'])
cantidad = len(tienda3['Costo de envío'])

promedio_envio = total_envio / cantidad if cantidad > 0 else 0

print(f"Costo de envío promedio general en la Tienda 3: {promedio_envio:.1f}")
# Out:
# Costo de envío promedio general en la Tienda 3: 24805.7

# %%
#Tienda 4

total_envio = sum(tienda4['Costo de envío'])
cantidad = len(tienda4['Costo de envío'])

promedio_envio = total_envio / cantidad if cantidad > 0 else 0

print(f"Costo de envío promedio general en la Tienda 4: {promedio_envio:.1f}")
# Out:
# Costo de envío promedio general en la Tienda 4: 23459.5

# %% [markdown]
# # 6. Generando gráficos

# %%
#Tienda 1

import matplotlib.pyplot as plt

ventas_por_producto = tienda['Producto'].value_counts().head(10)

plt.figure(figsize=(10,6))
ventas_por_producto.plot(kind='bar', color='skyblue')
plt.title('Top 10 Productos más vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad de ventas')
plt.tight_layout()
plt.show()

# %%
#Tienda 1

ventas_por_producto = tienda['Producto'].value_counts()

menos_vendidos = ventas_por_producto.tail(10)

plt.figure(figsize=(10,6))
menos_vendidos.plot(kind='bar', color='salmon')
plt.title('Top 10 Productos menos vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad de ventas')
plt.tight_layout()
plt.show()

# %%
#Tienda 1

categoria_counts = tienda['Categoría del Producto'].value_counts()

plt.figure(figsize=(8,8))
categoria_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Categorías de Producto')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
#Tienda 1
calif_promedio = tienda.groupby('Lugar de Compra')['Calificación'].mean().sort_values(ascending=False)

# Graficar
plt.figure(figsize=(8,5))
plt.plot(calif_promedio.index, calif_promedio.values, marker='o', linestyle='-', color='royalblue')
plt.title('Calificación promedio por tienda')
plt.ylabel('Calificación promedio')
plt.xlabel('Lugar de compra')
plt.ylim(0, 5)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # 7. Desafío extra

# %%
#Tienda 1

plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=tienda, x='lon', y='lat', weights=tienda['Precio'],
    cmap="Reds", fill=True, thresh=0.05, levels=100
)
plt.title('Mapa de calor de ingresos – Tienda 1')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()

# %%
#Tienda 2

plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=tienda2, x='lon', y='lat', weights=tienda2['Precio'],
    cmap="Reds", fill=True, thresh=0.05, levels=100
)
plt.title('Mapa de calor de ingresos – Tienda 2')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()

# %%
#Tienda 3

plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=tienda3, x='lon', y='lat', weights=tienda3['Precio'],
    cmap="Reds", fill=True, thresh=0.05, levels=100
)
plt.title('Mapa de calor de ingresos – Tienda 3')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()

# %%
#Tienda 4

plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=tienda, x='lon', y='lat', weights=tienda['Precio'],
    cmap="Reds", fill=True, thresh=0.05, levels=100
)
plt.title('Mapa de calor de ingresos – Tienda 4')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()

# %% [markdown]
# # 8. Informe final

# %% [markdown]
# # Informe Final: Recomendación de tienda para el Sr. Juan
#
# ## Introducción
#
# El objetivo de este análisis es determinar cuál de las cuatro tiendas evaluadas representa la mejor opción para que el Sr. Juan venda sus productos. Para tomar una decisión informada, se consideraron diversos factores clave: el ingreso total generado por cada tienda, las categorías de productos más y menos vendidos, la calificación promedio otorgada por los clientes, los productos más y menos vendidos en cada tienda, y el costo promedio de envío. Los datos se analizaron y visualizaron mediante gráficos, con el fin de identificar patrones y evaluar el desempeño general de cada tienda.
#
# ## Desarrollo del análisis
#
# ### 1. Ingreso total por tienda
#
# El análisis de los ingresos totales muestra que:
#
# | Tienda   | Ingreso total          |
# |----------|------------------------|
# | Tienda 1 | 1,150,880,400          |
# | Tienda 2 | 1,116,343,500          |
# | Tienda 3 | 1,098,019,600          |
# | Tienda 4 | 1,038,375,700          |
#
# **Observación:** La Tienda 1 lidera en generación de ingresos, lo que indica un alto volumen de ventas y/o productos de mayor precio.
#
# ---
#
# ### 2. Ventas por categoría
#
# | Tienda   | Más vendida             | Menos vendida                     |
# |----------|-------------------------|-----------------------------------|
# | Tienda 1 | Muebles (465)           | Artículos para el hogar (171)     |
# | Tienda 2 | Muebles (442)           | Artículos para el hogar (181)     |
# | Tienda 3 | Muebles (499)           | Artículos para el hogar, Instrumentos musicales (177)     |
# | Tienda 4 | Muebles (480)           | Instrumentos musicales (170)      |
#
# **Observación:** La categoría "Muebles" lidera en todas las tiendas, lo que sugiere una fuerte demanda. Las categorías con menor rotación son "Artículos para el hogar" e "Instrumentos musicales".
#
# ---
#
# ### 3. Calificación promedio
#
# | Tienda   | Calificación promedio |
# |----------|------------------------|
# | Tienda 1 | 3.98                   |
# | Tienda 2 | 4.04                   |
# | Tienda 3 | 4.05                   |
# | Tienda 4 | 4.00                   |
#
# **Observación:** La Tienda 3 cuenta con la mejor valoración de los clientes, lo cual puede reflejar mejor atención, calidad de servicio o experiencia de compra.
#
# ---
#
# ### 4. Productos más y menos vendidos
#
# - **Tienda 1:**
#   - Más vendidos: Microondas, TV LED UHD 4K, Armario (60 unidades)
#   - Menos vendidos: Auriculares con micrófono, Celular ABXY (33 unidades)
#
# - **Tienda 2:**
#   - Más vendido: Iniciando en programación (65 unidades)
#   - Menos vendido: Juego de mesa (32 unidades)
#
# - **Tienda 3:**
#   - Más vendido: Kit de bancas (57 unidades)
#   - Menos vendido: Bloques de construcción (35 unidades)
#
# - **Tienda 4:**
#   - Más vendido: Cama box (62 unidades)
#   - Menos vendidos: Guitarra eléctrica (33 unidades)
#
# **Observación:** Los productos más vendidos varían entre tiendas, lo que indica diferencias en preferencias de los clientes. "Auriculares con micrófono" se repite como uno de los menos vendidos.
#
# ---
#
# ### 5. Costo de envío promedio
#
# | Tienda   | Costo de envío promedio (CLP) |
# |----------|-------------------------------|
# | Tienda 1 | *26,018.6*             |
# | Tienda 2 | *25,216.2*             |
# | Tienda 3 | *24,805.7*             |
# | Tienda 4 | *23,459.5*             |
#
# **Observación:** Un menor costo de envío puede mejorar la competitividad de los productos del Sr. Juan. Este factor debe considerarse si existen diferencias significativas.
#
# ---
#
# ## Conclusión y recomendación
#
# Después de evaluar los distintos factores analizados, se concluye que:
#
# - La **Tienda 1** tiene el mayor ingreso total, lo que la convierte en una opción atractiva en términos de volumen de ventas.
# - La **Tienda 3** destaca por su **mejor calificación promedio**, lo cual sugiere una mejor experiencia para el cliente.
# - La categoría "Muebles", dominante en todas las tiendas, representa una oportunidad si los productos del Sr. Juan se alinean con esta tendencia.
# - El **costo de envío promedio** en la Tienda 3 no es excesivo por lo que se presenta como la opción más equilibrada entre ingresos, satisfacción del cliente y rotación de productos.
#
# **Recomendación final:** Se recomienda al Sr. Juan vender sus productos en la **Tienda 3**, debido a su combinación favorable de buena reputación, ventas competitivas y fuerte demanda en la categoría de muebles. Esta tienda representa la mejor oportunidad para posicionar sus productos de manera sostenible y con buen potencial de crecimiento.
